# %% [markdown]
# Abhinav Kochar

# %% [markdown]
# # Streamlit-based RAG with Wikipedia Data

# %%
# !pip install streamlit wikipedia-api sentence-transformers pyngrok
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import wikipediaapi
from sentence_transformers import SentenceTransformer
from pyngrok import ngrok
import os
import pandas as pd

# Function to fetch Wikipedia summary
def fetch_wikipedia_summary(query):
    wiki = wikipediaapi.Wikipedia(language='en', user_agent="Mozilla/5.0 (compatible; MyBot/0.1; +http://mybot.com/info)")
    page = wiki.page(query)
    if page.exists():
        return page.summary
    else:
        return "No Wikipedia page found for the given query."

# %%
# Load the sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
# %%writefile app.py

import streamlit as st
from sentence_transformers import SentenceTransformer
import wikipediaapi

# Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')

def fetch_wikipedia_summary(query):
    wiki = wikipediaapi.Wikipedia(language='en', user_agent="Mozilla/5.0 (compatible; MyBot/0.1; +http://mybot.com/info)")
    page = wiki.page(query)
    if page.exists():
        return page.summary
    else:
        return "No Wikipedia page found for the given query."

st.title("Wikipedia RAG with Streamlit")

query = st.text_input("Enter a Wikipedia search query:")
if query:
    summary = fetch_wikipedia_summary(query)
    st.write(summary)
# Out:
# Writing app.py

# %%
# Set up ngrok
# !ngrok authtoken 2mtGkgWrUDortytaiWRmi2s1g2p_6SfQptscCjj5E17iMZ2Gc  # Replace with your actual ngrok token

public_url = ngrok.connect(8501)
print(f"Public URL: {public_url}")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public URL: NgrokTunnel: "https://724b-34-138-252-187.ngrok-free.app" -> "http://localhost:8501"

# %%
# Run the Streamlit app
# !streamlit run app.py &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.138.252.187:8501
#
#   Stopping...

# %%
# Step 1: Install Required Libraries
# !pip install streamlit faiss-cpu sentence-transformers pyngrok wikipedia-api

# Step 2: Import Required Libraries
import streamlit as st
import wikipediaapi
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from pyngrok import ngrok
import os
import subprocess

# Step 3: Load Sentence Transformer Model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Step 4: Initialize FAISS Index
d = 384  # Embedding dimension for MiniLM
index = faiss.IndexFlatL2(d)  # L2 distance-based FAISS index
stored_texts = []

# Step 5: Initialize Wikipedia API Properly
wiki = wikipediaapi.Wikipedia(
    user_agent="Mozilla/5.0 (compatible; MyBot/0.1; +http://mybot.com/info)",
    language="en"
)

# Step 6: Function to Fetch Wikipedia Summary
def fetch_wikipedia_summary(query):
    page = wiki.page(query)
    return page.summary if page.exists() else "No Wikipedia page found for the given query."

# Step 7: Function to Add Data to FAISS Index
def add_to_index(query):
    summary = fetch_wikipedia_summary(query)
    if summary != "No Wikipedia page found for the given query.":
        embedding = model.encode([summary])
        index.add(embedding.astype(np.float32))
        stored_texts.append((query, summary))
        return True
    return False

# Step 8: Function to Retrieve Similar Results
def retrieve_similar(query, top_k=3):
    query_embedding = model.encode([query]).astype(np.float32)
    _, I = index.search(query_embedding, top_k)  # Retrieve top_k results
    results = [stored_texts[i][1] for i in I[0] if i < len(stored_texts)]
    return results if results else ["No relevant results found."]

# Step 9: Save Streamlit Script
script_code = f"""
import streamlit as st
from sentence_transformers import SentenceTransformer
import wikipediaapi
import faiss
import numpy as np

# Load model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Initialize FAISS Index
d = 384
index = faiss.IndexFlatL2(d)
stored_texts = []

# Wikipedia API - Initialize Once
wiki = wikipediaapi.Wikipedia(
    user_agent="Mozilla/5.0 (compatible; MyBot/0.1; +http://mybot.com/info)",
    language="en"
)

# Wikipedia Fetch Function
def fetch_wikipedia_summary(query):
    page = wiki.page(query)
    return page.summary if page.exists() else "No Wikipedia page found."

# Add Data to Index
def add_to_index(query):
    summary = fetch_wikipedia_summary(query)
    if summary != "No Wikipedia page found.":
        embedding = model.encode([summary])
        index.add(embedding.astype(np.float32))
        stored_texts.append((query, summary))
        return True
    return False

# Retrieve Similar
def retrieve_similar(query, top_k=3):
    query_embedding = model.encode([query]).astype(np.float32)
    _, I = index.search(query_embedding, top_k)
    results = [stored_texts[i][1] for i in I[0] if i < len(stored_texts)]
    return results if results else ["No relevant results found."]

# Streamlit UI
st.title("Wikipedia RAG Search")
query = st.text_input("Enter your query:")
if st.button("Search"):
    if add_to_index(query):
        results = retrieve_similar(query)
        st.subheader("Retrieved Information:")
        for res in results:
            st.write(res)
    else:
        st.write("No relevant information found.")
"""

with open("app.py", "w") as f:
    f.write(script_code)

# Step 10: Authenticate ngrok and Start Streamlit
# !ngrok authtoken 2mtGkgWrUDortytaiWRmi2s1g2p_6SfQptscCjj5E17iMZ2Gc

# Step 11: Run Streamlit in Background
subprocess.Popen(["streamlit", "run", "app.py"])

# Step 12: Generate ngrok Public URL
public_url = ngrok.connect(8501)
print(f"Public URL: {public_url}")
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public URL: NgrokTunnel: "https://9f2f-34-138-252-187.ngrok-free.app" -> "http://localhost:8501"
